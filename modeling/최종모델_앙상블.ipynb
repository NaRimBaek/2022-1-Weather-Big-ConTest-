# %%
import numpy as np
import pandas as pd

from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # br_rf&lasso&2week&area_day_sex(2:2:1:5)

# %%
br_rf = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/220119(제출용)/220119_br_rf.csv')
lasso = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/stacking용/지역별_lasso.csv')
area_day = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/220119(제출용)/이짓거리/area_day_평균.csv')
area_day_sex = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/220119(제출용)/이짓거리/area_day_sex_평균.csv')
area_sex=pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/220119(제출용)/이짓거리/area_sex_평균.csv')

week_2 = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/220119(제출용)/220119_br2week.csv')

# %%
br_rf_freq = br_rf['frequency']
lasso_freq = lasso['frequency']
area_day_sex_freq = area_day_sex['frequency']
area_sex_freq = area_sex["frequency"]
area_day_freq = area_day['frequency']
week2_freq = week_2['frequency']

# %%
final_freq = (br_rf_freq * 0.1) + (lasso_freq * 0.05) + (week2_freq * 0.05) + (area_day_sex_freq * 0.4) + ( area_day_freq *0.3) + (area_sex_freq*0.1)
final_freq
# Out:
# 0        2.537402
# 1        5.750005
# 2        3.016806
# 3        3.923264
# 4        1.454562
#            ...
# 12439    1.762302
# 12440    1.210681
# 12441    0.258725
# 12442    1.093228
# 12443    0.863153
# Name: frequency, Length: 12444, dtype: float64

# %%
sub = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/220119(제출용)/2-2_검증데이터셋.csv', encoding='cp949')
sub['frequency'] = area_day_sex_freq

# %%
sub[sub['frequency']<0]
# Out:
# Empty DataFrame
# Columns: [yyyymmdd, area, sex, frequency]
# Index: []

# %%
sub.to_csv('/content/drive/MyDrive/날씨 빅콘/data/220119(제출용)/최종제출/개빡빡1.csv', index=False)
