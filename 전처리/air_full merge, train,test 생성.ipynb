# %%
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import pandas as pd
import datetime as dt

# %%
# 관측 full data
fulldata = pd.read_csv('/content/drive/MyDrive/22-2/날씨 빅콘/data/전처리데이터/full_가중치완료.csv')

# 인구수 data
airdata = pd.read_csv('/content/drive/MyDrive/22-2/날씨 빅콘/data/전처리데이터/air_가중치완료.csv')

# %%
fulldata.head()
# Out:
#   where         tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate    ss_dur  \
# 0    강원  2011-01-01   7.850279       4.969315  2.892098  49.720459  9.632331
# 1    강원  2011-01-02   7.931251       0.181203  2.391485  65.170244  9.635492
# 2    강원  2011-01-03  12.450344       3.307011  5.072551  40.736534  9.643030
# 3    강원  2011-01-04  18.978367       5.416715  5.420207  65.299808  9.648529
# 4    강원  2011-01-05   7.124591       1.884490  0.673377  55.632543  9.665648
#
#    sum_ss_hr     min_tg       avg_pa  ...  mi10_max_rn  hr1_max_rn  \
# 0   4.796755 -14.659467  1005.628270  ...     0.125700    0.315722
# 1   6.281668 -11.452727  1010.697746  ...     1.091020    1.942323
# 2   3.927993 -11.371531  1006.754722  ...     0.229578    0.458507
# 3   6.297054 -10.984929  1004.901477  ...     0.949966    1.213511
# 4   5.378367  -9.040578  1003.102944  ...     0.397661    0.487669
#
#    hr6_max_rn   n9_9_rn    avg_ta    max_ta     min_ta    avg_ws    max_ws  \
# ...

# %%
fulldata['tma'] = pd.to_datetime(fulldata['tma'] )

# %%
fulldata['tma']
# Out:
# 0       2011-01-01
# 1       2011-01-02
# 2       2011-01-03
# 3       2011-01-04
# 4       2011-01-05
#            ...
# 37259   2016-12-27
# 37260   2016-12-28
# 37261   2016-12-29
# 37262   2016-12-30
# 37263   2016-12-31
# Name: tma, Length: 37264, dtype: datetime64[ns]

# %%
airdata['측정일'] = airdata['측정일'].astype(str)
airdata['측정일'] = airdata['측정일'].str[:4] + '-' + airdata['측정일'].str[4:6] + '-' + airdata['측정일'].str[6:]
airdata['측정일'] = pd.to_datetime(airdata['측정일'] )

# %%
full_ver2 = pd.merge(fulldata, airdata, how = "outer", left_on=["where","tma"], right_on=["지역","측정일"])

# %%
full_ver2 = full_ver2.drop(["지역","측정일"], axis=1)
# Out:
#       where        tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate  \
# 0        강원 2011-01-01   7.850279       4.969315  2.892098  49.720459
# 1        강원 2011-01-02   7.931251       0.181203  2.391485  65.170244
# 2        강원 2011-01-03  12.450344       3.307011  5.072551  40.736534
# 3        강원 2011-01-04  18.978367       5.416715  5.420207  65.299808
# 4        강원 2011-01-05   7.124591       1.884490  0.673377  55.632543
# ...     ...        ...        ...            ...       ...        ...
# 37259    세종 2016-12-27   1.600000       0.100000  0.100000  60.800000
# 37260    세종 2016-12-28   1.500000       0.000000  0.000000  87.600000
# 37261    세종 2016-12-29   2.000000       0.300000  0.400000  79.200000
# 37262    세종 2016-12-30   1.800000       0.100000  0.100000  84.700000
# 37263    세종 2016-12-31   0.600000       0.000000  0.000000  11.700000
#
#          ss_dur  sum_ss_hr     min_tg       avg_pa  ...    max_ta     min_ta  \
# ...

# %%
full_ver2.to_csv('/content/drive/MyDrive/22-2/날씨 빅콘/data/전처리데이터/full_air_통합.csv', index = False)

# %%
full_ver2 = pd.read_csv('/content/drive/MyDrive/22-2/날씨 빅콘/data/전처리데이터/full_air_통합.csv')

back_hospital = pd.read_csv('/content/drive/MyDrive/22-2/날씨 빅콘/data/back_hospital.csv')
back_hospital.head()
# Out:
#    Unnamed: 0  back_hospital.yyyymmdd back_hospital.area  back_hospital.sex  \
# 0           1                20120101                 강원                  1
# 1           2                20120101                 강원                  2
# 2           3                20120101                 경기                  1
# 3           4                20120101                 경기                  2
# 4           5                20120101                 경남                  1
#
#    back_hospital.frequency
# 0                        3
# 1                        3
# 2                        4
# 3                        5
# 4                        2

# %%
back_hospital=back_hospital.iloc[:,1:5]

# %%
back_hospital.head()
# Out:
#    back_hospital.yyyymmdd back_hospital.area  back_hospital.sex  \
# 0                20120101                 강원                  1
# 1                20120101                 강원                  2
# 2                20120101                 경기                  1
# 3                20120101                 경기                  2
# 4                20120101                 경남                  1
#
#    back_hospital.frequency
# 0                        3
# 1                        3
# 2                        4
# 3                        5
# 4                        2

# %%
back_hospital.columns = ['yyyymmdd', 'area','sex','frequency']

# %%
back_hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49674 entries, 0 to 49673
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   yyyymmdd   49674 non-null  int64
#  1   area       49674 non-null  object
#  2   sex        49674 non-null  int64
#  3   frequency  49674 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
back_hospital['yyyymmdd'] = back_hospital['yyyymmdd'].astype(str)
back_hospital['yyyymmdd'] = back_hospital['yyyymmdd'].str[:4] + '-' + back_hospital['yyyymmdd'].str[4:6] + '-' + back_hospital['yyyymmdd'].str[6:]
back_hospital['yyyymmdd'] = pd.to_datetime(back_hospital['yyyymmdd'] )

# %%
back_hospital.head(30)
# Out:
#      yyyymmdd area  sex  frequency
# 0  2012-01-01   강원    1          3
# 1  2012-01-01   강원    2          3
# 2  2012-01-01   경기    1          4
# 3  2012-01-01   경기    2          5
# 4  2012-01-01   경남    1          2
# 5  2012-01-01   경남    2          1
# 6  2012-01-01   경북    1          6
# 7  2012-01-01   경북    2          1
# 8  2012-01-01   광주    1          0
# 9  2012-01-01   광주    2          2
# 10 2012-01-01   대구    1          1
# 11 2012-01-01   대구    2          0
# 12 2012-01-01   대전    1          4
# 13 2012-01-01   대전    2          1
# 14 2012-01-01   부산    1          3
# 15 2012-01-01   부산    2          6
# 16 2012-01-01   서울    1          2
# 17 2012-01-01   서울    2          6
# 18 2012-01-01   세종    1          0
# 19 2012-01-01   세종    2          0
# 20 2012-01-01   울산    1          0
# 21 2012-01-01   울산    2          0
# 22 2012-01-01   인천    1          1
# 23 2012-01-01   인천    2          1
# 24 2012-01-01   전남    1          3
# 25 2012-01-01   전남    2          6
# ...

# %%
back_hospital.shape
# Out:
# (49674, 4)

# %%
full_ver2['tma'] = pd.to_datetime(full_ver2['tma'] )
full_ver2.head()
# Out:
#   where        tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate    ss_dur  \
# 0    강원 2011-01-01   7.850279       4.969315  2.892098  49.720459  9.632331
# 1    강원 2011-01-02   7.931251       0.181203  2.391485  65.170244  9.635492
# 2    강원 2011-01-03  12.450344       3.307011  5.072551  40.736534  9.643030
# 3    강원 2011-01-04  18.978367       5.416715  5.420207  65.299808  9.648529
# 4    강원 2011-01-05   7.124591       1.884490  0.673377  55.632543  9.665648
#
#    sum_ss_hr     min_tg       avg_pa  ...    max_ta     min_ta    avg_ws  \
# 0   4.796755 -14.659467  1005.628270  ... -0.063789 -12.208051  1.547175
# 1   6.281668 -11.452727  1010.697746  ...  2.585174  -9.332026  1.038441
# 2   3.927993 -11.371531  1006.754722  ...  1.801398  -9.576432  1.049815
# 3   6.297054 -10.984929  1004.901477  ...  1.864590  -8.671914  1.529719
# 4   5.378367  -9.040578  1003.102944  ...  1.044720  -6.814733  2.792736
#
# ...

# %%
full_ver3=full_ver2[(full_ver2['tma']>="2012-01-01") & (full_ver2['tma']<"2016-01-01")]
full_ver3.shape
# Out:
# (24837, 34)

# %%
test1=full_ver2[ (full_ver2['tma']>="2016-01-01")]

# %%
test1.head()
# Out:
#       where        tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate  \
# 29216    강원 2016-01-01  25.262803       8.088057  6.832984  41.929419
# 29217    강원 2016-01-02   8.681586       1.042484  2.071409  39.097954
# 29218    강원 2016-01-03  11.629889       1.968260  1.640193  52.701883
# 29219    강원 2016-01-04  13.101164       7.196318  3.888484  79.187951
# 29220    강원 2016-01-05  12.545928       1.995445  7.573693  71.737496
#
#          ss_dur  sum_ss_hr    min_tg       avg_pa  ...     max_ta    min_ta  \
# 29216  9.633102   4.029989 -8.917460  1014.162724  ...   5.029691 -3.663738
# 29217  9.636116   3.763058 -2.491278  1006.696135  ...   9.361337  1.906120
# 29218  9.643381   5.088184 -3.622101  1003.699089  ...  10.402122  1.342914
# 29219  9.643381   7.635405 -5.761820  1005.992442  ...   8.444949 -0.165044
# 29220  9.665488   6.929150 -9.969253  1010.055664  ...   4.104498 -4.087252
#
#          avg_ws    max_ws  max_ins_ws       SO2        CO        O3       NO2  \
# ...

# %%
test1.tail()
# Out:
#       where        tma  dd_mes  sum_dpth_fhsc  dd_mefs  ssrate  ss_dur  \
# 37259    세종 2016-12-27     1.6            0.1      0.1    60.8     9.7
# 37260    세종 2016-12-28     1.5            0.0      0.0    87.6     9.7
# 37261    세종 2016-12-29     2.0            0.3      0.4    79.2     9.7
# 37262    세종 2016-12-30     1.8            0.1      0.1    84.7     9.7
# 37263    세종 2016-12-31     0.6            0.0      0.0    11.7     9.7
#
#        sum_ss_hr  min_tg  avg_pa  ...  max_ta  min_ta  avg_ws  max_ws  \
# 37259        5.9    -8.8  1011.3  ...     3.2    -5.5     2.4     5.3
# 37260        8.5   -10.6  1018.3  ...     3.7    -8.8     0.8     2.6
# 37261        7.7    -9.1  1018.8  ...     0.5    -6.2     1.8     4.9
# 37262        8.2   -11.5  1021.3  ...     3.7    -9.4     0.8     2.7
# 37263        1.1    -6.5  1018.7  ...     4.4    -3.9     0.6     1.8
#
#        max_ins_ws       SO2        CO        O3       NO2       PM10
# ...

# %%
test1.shape
# Out:
# (6222, 34)

# %%
full_ver3.head()
# Out:
#      where        tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate  \
# 5840    강원 2012-01-01  10.136053       2.155943  1.303480  35.856285
# 5841    강원 2012-01-02   7.417967       3.311459  2.617197  59.931489
# 5842    강원 2012-01-03   7.610803       1.300557  1.469254  49.118485
# 5843    강원 2012-01-04   5.541347       1.899121  0.085333  74.463137
# 5844    강원 2012-01-05  12.253857       4.597339  4.816085  86.004346
#
#         ss_dur  sum_ss_hr     min_tg       avg_pa  ...    max_ta     min_ta  \
# 5840  9.632506   3.444997  -9.869523  1007.235630  ...  2.045879  -6.453899
# 5841  9.607047   5.758478 -11.479135  1009.604790  ...  0.590183  -9.040547
# 5842  9.643024   4.737987 -10.719102  1004.681326  ...  1.190765  -8.520792
# 5843  9.643024   7.180653 -11.051288  1007.651489  ... -1.996573  -9.506732
# 5844  9.665621   8.311581 -13.312470  1012.024888  ... -0.009856 -11.955211
#
#         avg_ws    max_ws  max_ins_ws       SO2        CO        O3       NO2  \
# ...

# %%
full_ver3["where"].unique()
# Out:
# array(['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '서울', '울산', '인천',
#        '전남', '전북', '제주', '충남', '충북', '세종'], dtype=object)

# %%
back_hospital.area.unique()
# Out:
# array(['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '서울', '세종', '울산',
#        '인천', '전남', '전북', '제주', '충남', '충북'], dtype=object)

# %%
full_ver4 = pd.merge(back_hospital,full_ver3, how = "outer", left_on=["area","yyyymmdd"], right_on=["where","tma"])
# Out:
#      yyyymmdd area  sex  frequency where        tma     dd_mes  sum_dpth_fhsc  \
# 0  2012-01-01   강원    1          3    강원 2012-01-01  10.136053       2.155943
# 1  2012-01-01   강원    2          3    강원 2012-01-01  10.136053       2.155943
# 2  2012-01-01   경기    1          4    경기 2012-01-01   1.029764       0.085438
# 3  2012-01-01   경기    2          5    경기 2012-01-01   1.029764       0.085438
# 4  2012-01-01   경남    1          2    경남 2012-01-01   0.865082       0.293056
# 5  2012-01-01   경남    2          1    경남 2012-01-01   0.865082       0.293056
# 6  2012-01-01   경북    1          6    경북 2012-01-01   5.110335       0.787695
# 7  2012-01-01   경북    2          1    경북 2012-01-01   5.110335       0.787695
# 8  2012-01-01   광주    1          0    광주 2012-01-01   0.100000       0.100000
# 9  2012-01-01   광주    2          2    광주 2012-01-01   0.100000       0.100000
# 10 2012-01-01   대구    1          1    대구 2012-01-01   0.300000       0.300000
# ...

# %%
full_ver4 = full_ver4.drop(['where','tma'],axis=1)

# %%
full_ver4.shape
# Out:
# (49674, 36)

# %%
full_ver4.head()
# Out:
#     yyyymmdd area  sex  frequency     dd_mes  sum_dpth_fhsc   dd_mefs  \
# 0 2012-01-01   강원    1          3  10.136053       2.155943  1.303480
# 1 2012-01-01   강원    2          3  10.136053       2.155943  1.303480
# 2 2012-01-01   경기    1          4   1.029764       0.085438  0.096118
# 3 2012-01-01   경기    2          5   1.029764       0.085438  0.096118
# 4 2012-01-01   경남    1          2   0.865082       0.293056  0.533394
#
#       ssrate    ss_dur  sum_ss_hr  ...    max_ta    min_ta    avg_ws  \
# 0  35.856285  9.632506   3.444997  ...  2.045879 -6.453899  1.780413
# 1  35.856285  9.632506   3.444997  ...  2.045879 -6.453899  1.780413
# 2  25.748326  9.669065   2.485800  ...  0.721111 -7.679919  1.823096
# 3  25.748326  9.669065   2.485800  ...  0.721111 -7.679919  1.823096
# 4  29.514334  9.814313   2.896959  ...  7.408240 -2.418864  2.114119
#
#      max_ws  max_ins_ws       SO2        CO        O3       NO2       PM10
# ...

# %%
full_ver4.to_csv('/content/drive/MyDrive/22-2/날씨 빅콘/data/전처리데이터/train.csv', index = False)

# %%
test1.head()
# Out:
#       where        tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate  \
# 29216    강원 2016-01-01  25.262803       8.088057  6.832984  41.929419
# 29217    강원 2016-01-02   8.681586       1.042484  2.071409  39.097954
# 29218    강원 2016-01-03  11.629889       1.968260  1.640193  52.701883
# 29219    강원 2016-01-04  13.101164       7.196318  3.888484  79.187951
# 29220    강원 2016-01-05  12.545928       1.995445  7.573693  71.737496
#
#          ss_dur  sum_ss_hr    min_tg       avg_pa  ...     max_ta    min_ta  \
# 29216  9.633102   4.029989 -8.917460  1014.162724  ...   5.029691 -3.663738
# 29217  9.636116   3.763058 -2.491278  1006.696135  ...   9.361337  1.906120
# 29218  9.643381   5.088184 -3.622101  1003.699089  ...  10.402122  1.342914
# 29219  9.643381   7.635405 -5.761820  1005.992442  ...   8.444949 -0.165044
# 29220  9.665488   6.929150 -9.969253  1010.055664  ...   4.104498 -4.087252
#
#          avg_ws    max_ws  max_ins_ws       SO2        CO        O3       NO2  \
# ...

# %%
validation = pd.read_csv('/content/drive/MyDrive/22-2/날씨 빅콘/data/2-2_검증데이터셋.csv',encoding='CP949')

# %%
validation.head()
# Out:
#      yyyymmdd area  sex  frequency
# 0  2016-01-01   강원    1        NaN
# 1  2016-01-01   경기    1        NaN
# 2  2016-01-01   경남    1        NaN
# 3  2016-01-01   경북    1        NaN
# 4  2016-01-01   광주    1        NaN

# %%
validation['yyyymmdd'] =pd.to_datetime( validation['yyyymmdd'] )

# %%
test2 = pd.merge(validation,test1, how = "outer", left_on=["area","yyyymmdd"], right_on=["where","tma"])
test2.head()
# Out:
#     yyyymmdd area  sex  frequency where        tma     dd_mes  sum_dpth_fhsc  \
# 0 2016-01-01   강원    1        NaN    강원 2016-01-01  25.262803       8.088057
# 1 2016-01-01   강원    2        NaN    강원 2016-01-01  25.262803       8.088057
# 2 2016-01-01   경기    1        NaN    경기 2016-01-01   3.140683       0.247502
# 3 2016-01-01   경기    2        NaN    경기 2016-01-01   3.140683       0.247502
# 4 2016-01-01   경남    1        NaN    경남 2016-01-01   0.415067       0.216473
#
#     dd_mefs     ssrate  ...    max_ta    min_ta    avg_ws    max_ws  \
# 0  6.832984  41.929419  ...  5.029691 -3.663738  1.603452  3.848153
# 1  6.832984  41.929419  ...  5.029691 -3.663738  1.603452  3.848153
# 2  0.263841  19.758979  ...  5.124417 -5.180968  0.831698  2.227017
# 3  0.263841  19.758979  ...  5.124417 -5.180968  0.831698  2.227017
# 4  0.155119  86.066663  ...  8.897572 -2.814340  1.516712  3.954204
#
#    max_ins_ws       SO2        CO        O3       NO2       PM10
# ...

# %%
test2.shape
# Out:
# (12444, 35)

# %%
test2.drop(['frequency','where','tma'], axis = 1,inplace=True)

# %%
test2.to_csv('/content/drive/MyDrive/22-2/날씨 빅콘/data/전처리데이터/test.csv', index = False)
