# %%
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import pandas as pd
import datetime as dt

# %%
train = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/전처리데이터/train_test/ver_0804/train_0804_3.csv')
test =  pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/전처리데이터/train_test/ver_0804/test_0804_3.csv')

# %%
train.head(100)
# Out:
#         yyyymmdd area  sex  frequency     dd_mes  sum_dpth_fhsc    dd_mefs  \
# 0     2012-01-01   강원    1          3  10.136053       2.155943   1.303480
# 34    2012-01-02   강원    1          2   7.417967       3.311459   2.617197
# 68    2012-01-03   강원    1          0   7.610803       1.300557   1.469254
# 102   2012-01-04   강원    1          1   5.541347       1.899121   0.085333
# 136   2012-01-05   강원    1          2  12.253857       4.597339   4.816085
# 170   2012-01-06   강원    1          2   5.621090       0.907107   0.525725
# 204   2012-01-07   강원    1          1  24.088847       5.788735   3.427674
# 238   2012-01-08   강원    1          0  18.141765       7.086251   4.419109
# 272   2012-01-09   강원    1          1   6.640594       1.473444   1.913178
# 306   2012-01-10   강원    1          1   5.227940       0.486313   0.596939
# 340   2012-01-11   강원    1          0  19.389044       2.377107   2.322580
# ...

# %%
#train = train.sort_index()

# %%
pd.set_option('display.max_rows', 100)

# %%
train[['frequency','freq_lag14']].head(50)

# %%
train[train['frequency']>=6][['frequency','freq_lag14']].head(50)
# Out:
#        frequency  freq_lag14
# 5168           6         3.0
# 28934          6         1.0
# 29988          8         0.0
# 35734          6         0.0
# 40324          6         1.0
# 41208          6         4.0
# 42398          6         2.0
# 43418          6         2.0
# 70             7         4.0
# 138           12         4.0
# 274            6         4.0
# 308            7         4.0
# 342           11         4.0
# 410            7         4.0
# 546            6         7.0
# 818            8        11.0
# 852            6         5.0
# 886            8         7.0
# 954            6         4.0
# 1022           8         6.0
# 1226           7         2.0
# 1532           6         3.0
# 1668           9         2.0
# 1736           7         4.0
# 1804          11         5.0
# 1906           7         4.0
# 1974           9         3.0
# 2076           9         2.0
# 2144           6         9.0
# 2178           6         5.0
# 2212          10         7.0
# ...

# %%
freq = train['frequency']
freq_14 = train['freq_lag14']

# %%
df = train[['frequency','freq_lag14']]
df.corr()
# Out:
#             frequency  freq_lag14
# frequency     1.00000     0.47062
# freq_lag14    0.47062     1.00000

# %%
train.iloc[:, 112:117].columns
# Out:
# Index(['SO2', 'CO', 'O3', 'NO2', 'PM10'], dtype='object')

# %%
train[['yyyymmdd']].dtypes
# Out:
# yyyymmdd    object
# dtype: object

# %%
train['yyyymmdd'] =

# %%
train.head()

# %%
train = train.sort_values(['area','sex'])
train['freq_lag1'] = train.groupby(['area','sex'])['frequency'].shift(1)
train['freq_lag2'] = train.groupby(['area','sex'])['frequency'].shift(2)
train['freq_lag3'] = train.groupby(['area','sex'])['frequency'].shift(3)
train['freq_lag4'] = train.groupby(['area','sex'])['frequency'].shift(4)
train['freq_lag5'] = train.groupby(['area','sex'])['frequency'].shift(5)
train['freq_lag14'] = train.groupby(['area','sex'])['frequency'].shift(14)
train['freq_lag28'] = train.groupby(['area','sex'])['frequency'].shift(28)
train = train.fillna(method='bfill')

# %%
train.head()
# Out:
#        yyyymmdd area  sex  frequency     dd_mes  sum_dpth_fhsc   dd_mefs  \
# 0    2012-01-01   강원    1          3  10.136053       2.155943  1.303480
# 34   2012-01-02   강원    1          2   7.417967       3.311459  2.617197
# 68   2012-01-03   강원    1          0   7.610803       1.300557  1.469254
# 102  2012-01-04   강원    1          1   5.541347       1.899121  0.085333
# 136  2012-01-05   강원    1          2  12.253857       4.597339  4.816085
#
#         ssrate    ss_dur  sum_ss_hr  ...  D02_range_48_lag19  \
# 0    35.856285  9.632506   3.444997  ...                 0.0
# 34   59.931489  9.607047   5.758478  ...                 0.0
# 68   49.118485  9.643024   4.737987  ...                 0.0
# 102  74.463137  9.643024   7.180653  ...                 0.0
# 136  86.004346  9.665621   8.311581  ...                 0.0
#
#      D02_range_48_lag20  D02_range_48_lag21  freq_lag1  freq_lag2  freq_lag3  \
# 0                   0.0                 0.0        3.0        3.0        3.0
# ...

# %%
train = train.sort_index()

# %%
train.head()

# %%
train.isnull().sum()
# Out:
# yyyymmdd      0
# area          0
# sex           0
# frequency     0
# dd_mes        0
#              ..
# freq_lag3     0
# freq_lag4     0
# freq_lag5     0
# freq_lag14    0
# freq_lag28    0
# Length: 1697, dtype: int64

# %%
train.to_csv('/content/drive/MyDrive/날씨 빅콘/data/전처리데이터/train_test/ver_0804/train_0804_4.csv', index=False)

# %%
train = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/전처리데이터/train_test/ver_0804/train_0804_4.csv')

# %%
train.head()
# Out:
#      yyyymmdd area  sex  frequency     dd_mes  sum_dpth_fhsc   dd_mefs  \
# 0  2012-01-01   강원    1          3  10.136053       2.155943  1.303480
# 1  2012-01-01   강원    2          3  10.136053       2.155943  1.303480
# 2  2012-01-01   경기    1          4   1.029764       0.085438  0.096118
# 3  2012-01-01   경기    2          5   1.029764       0.085438  0.096118
# 4  2012-01-01   경남    1          2   0.865082       0.293056  0.533394
#
#       ssrate    ss_dur  sum_ss_hr  ...  D02_range_48_lag19  \
# 0  35.856285  9.632506   3.444997  ...                 0.0
# 1  35.856285  9.632506   3.444997  ...                 0.0
# 2  25.748326  9.669065   2.485800  ...                 0.0
# 3  25.748326  9.669065   2.485800  ...                 0.0
# 4  29.514334  9.814313   2.896959  ...                 0.0
#
#    D02_range_48_lag20  D02_range_48_lag21  freq_lag1  freq_lag2  freq_lag3  \
# 0                 0.0                 0.0        3.0        3.0        3.0
# ...
