# %%
import os

# !pip install -q datatable
import datatable as dt 

import pandas as pd
import numpy as np
# Out:
#      |████████████████████████████████| 96.9 MB 102 kB/s
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# ...

# %%
# 구글 드라이브 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/날씨 빅콘/data/건강데이터"
os.chdir(path)

# %%
data = pd.read_csv('{}/최종/total_data_lag_1_new.csv'.format(path))

# %%
data.head)
# Out:
#   where         tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate    ss_dur  \
# 0    강원  2011-01-01   7.850279       4.969315  2.892098  49.720459  9.632331
# 1    강원  2011-01-02   7.931251       0.181203  2.391485  65.170244  9.635492
# 2    강원  2011-01-03  12.450344       3.307011  5.072551  40.736534  9.643030
# 3    강원  2011-01-04  18.978367       5.416715  5.420207  65.299808  9.648529
# 4    강원  2011-01-05   7.124591       1.884490  0.673377  55.632543  9.665648
#
#    sum_ss_hr     min_tg       avg_pa  ...  mi10_max_rn  hr1_max_rn  \
# 0   4.796755 -14.659467  1005.628270  ...     0.125700    0.315722
# 1   6.281668 -11.452727  1010.697746  ...     1.091020    1.942323
# 2   3.927993 -11.371531  1006.754722  ...     0.229578    0.458507
# 3   6.297054 -10.984929  1004.901477  ...     0.949966    1.213511
# 4   5.378367  -9.040578  1003.102944  ...     0.397661    0.487669
#
#    hr6_max_rn   n9_9_rn    avg_ta    max_ta     min_ta    avg_ws    max_ws  \
# ...

# %%
data.isna().sum()
# Out:
# where            0
# tma              0
# dd_mes           0
# sum_dpth_fhsc    0
# dd_mefs          0
# ssrate           0
# ss_dur           0
# sum_ss_hr        0
# min_tg           0
# avg_pa           0
# max_pa           0
# min_pa           0
# avg_pv           0
# max_pv           0
# min_pv           0
# avg_rhm          0
# min_rhm          0
# sum_rn           0
# sum_rn_dur       0
# mi10_max_rn      0
# hr1_max_rn       0
# hr6_max_rn       0
# n9_9_rn          0
# avg_ta           0
# max_ta           0
# min_ta           0
# avg_ws           0
# max_ws           0
# max_ins_ws       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['where', 'tma', 'dd_mes', 'sum_dpth_fhsc', 'dd_mefs', 'ssrate',
#        'ss_dur', 'sum_ss_hr', 'min_tg', 'avg_pa', 'max_pa', 'min_pa', 'avg_pv',
#        'max_pv', 'min_pv', 'avg_rhm', 'min_rhm', 'sum_rn', 'sum_rn_dur',
#        'mi10_max_rn', 'hr1_max_rn', 'hr6_max_rn', 'n9_9_rn', 'avg_ta',
#        'max_ta', 'min_ta', 'avg_ws', 'max_ws', 'max_ins_ws'],
#       dtype='object')

# %%
lag_columns = ['dd_mes', 'sum_dpth_fhsc', 'dd_mefs', 'ssrate','ss_dur', 'sum_ss_hr', 'min_tg', 'avg_pa', 'max_pa', 'min_pa', 'avg_pv',
               'max_pv', 'min_pv', 'avg_rhm', 'min_rhm', 'sum_rn', 'sum_rn_dur','mi10_max_rn', 'hr1_max_rn', 'hr6_max_rn', 'n9_9_rn', 'avg_ta',
               'max_ta', 'min_ta', 'avg_ws', 'max_ws', 'max_ins_ws']

# %%
lag1_columns = ['dd_mes_lag1', 'sum_dpth_fhsc_lag1', 'dd_mefs_lag1', 'ssrate_lag1','ss_dur_lag1', 'sum_ss_hr_lag1', 'min_tg_lag1', 'avg_pa_lag1', 'max_pa_lag1', 'min_pa_lag1', 'avg_pv_lag1',
               'max_pv_lag1', 'min_pv_lag1', 'avg_rhm_lag1', 'min_rhm_lag1', 'sum_rn_lag1', 'sum_rn_dur_lag1','mi10_max_rn_lag1', 'hr1_max_rn_lag1', 'hr6_max_rn_lag1', 'n9_9_rn_lag1', 'avg_ta_lag1',
               'max_ta_lag1', 'min_ta_lag1', 'avg_ws_lag1', 'max_ws_lag1', 'max_ins_ws_lag1']

# %%
lag2_columns = ['dd_mes_lag2', 'sum_dpth_fhsc_lag2', 'dd_mefs_lag2', 'ssrate_lag2','ss_dur_lag2', 'sum_ss_hr_lag2', 'min_tg_lag2', 'avg_pa_lag2', 'max_pa_lag2', 'min_pa_lag2', 'avg_pv_lag2',
               'max_pv_lag2', 'min_pv_lag2', 'avg_rhm_lag2', 'min_rhm_lag2', 'sum_rn_lag2', 'sum_rn_dur_lag2','mi10_max_rn_lag2', 'hr1_max_rn_lag2', 'hr6_max_rn_lag2', 'n9_9_rn_lag2', 'avg_ta_lag2',
               'max_ta_lag2', 'min_ta_lag2', 'avg_ws_lag2', 'max_ws_lag2', 'max_ins_ws_lag2']

# %%
lag3_columns = ['dd_mes_lag3', 'sum_dpth_fhsc_lag3', 'dd_mefs_lag3', 'ssrate_lag3','ss_dur_lag3', 'sum_ss_hr_lag3', 'min_tg_lag3', 'avg_pa_lag3', 'max_pa_lag3', 'min_pa_lag3', 'avg_pv_lag3',
               'max_pv_lag3', 'min_pv_lag3', 'avg_rhm_lag3', 'min_rhm_lag3', 'sum_rn_lag3', 'sum_rn_dur_lag3','mi10_max_rn_lag3', 'hr1_max_rn_lag3', 'hr6_max_rn_lag3', 'n9_9_rn_lag3', 'avg_ta_lag3',
               'max_ta_lag3', 'min_ta_lag3', 'avg_ws_lag3', 'max_ws_lag3', 'max_ins_ws_lag3']

# %%
data[lag1_columns] = data.groupby(by=['where'])[lag_columns].shift(1)

# %%
data[lag2_columns] = data.groupby(by=['where'])[lag_columns].shift(2)

# %%
data[lag3_columns] = data.groupby(by=['where'])[lag_columns].shift(3)

# %%
data.head()
# Out:
#   where         tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate    ss_dur  \
# 0    강원  2011-01-01   7.850279       4.969315  2.892098  49.720459  9.632331
# 1    강원  2011-01-02   7.931251       0.181203  2.391485  65.170244  9.635492
# 2    강원  2011-01-03  12.450344       3.307011  5.072551  40.736534  9.643030
# 3    강원  2011-01-04  18.978367       5.416715  5.420207  65.299808  9.648529
# 4    강원  2011-01-05   7.124591       1.884490  0.673377  55.632543  9.665648
#
#    sum_ss_hr     min_tg       avg_pa  ...  mi10_max_rn_lag3  hr1_max_rn_lag3  \
# 0   4.796755 -14.659467  1005.628270  ...               NaN              NaN
# 1   6.281668 -11.452727  1010.697746  ...               NaN              NaN
# 2   3.927993 -11.371531  1006.754722  ...               NaN              NaN
# 3   6.297054 -10.984929  1004.901477  ...           0.12570         0.315722
# 4   5.378367  -9.040578  1003.102944  ...           1.09102         1.942323
#
# ...

# %%
data = data.fillna(method='bfill')

# %%
data.head()
# Out:
#   where         tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate    ss_dur  \
# 0    강원  2011-01-01   7.850279       4.969315  2.892098  49.720459  9.632331
# 1    강원  2011-01-02   7.931251       0.181203  2.391485  65.170244  9.635492
# 2    강원  2011-01-03  12.450344       3.307011  5.072551  40.736534  9.643030
# 3    강원  2011-01-04  18.978367       5.416715  5.420207  65.299808  9.648529
# 4    강원  2011-01-05   7.124591       1.884490  0.673377  55.632543  9.665648
#
#    sum_ss_hr     min_tg       avg_pa  ...  mi10_max_rn_lag3  hr1_max_rn_lag3  \
# 0   4.796755 -14.659467  1005.628270  ...           0.12570         0.315722
# 1   6.281668 -11.452727  1010.697746  ...           0.12570         0.315722
# 2   3.927993 -11.371531  1006.754722  ...           0.12570         0.315722
# 3   6.297054 -10.984929  1004.901477  ...           0.12570         0.315722
# 4   5.378367  -9.040578  1003.102944  ...           1.09102         1.942323
#
# ...

# %%
data.to_csv("/content/drive/MyDrive/날씨 빅콘/data/전처리데이터/full_가중치완료_lag.csv",index=False)

# %%
pd.set_option('display.max_columns', 100)

# %%
data[730:735]
# Out:
#     where         tma    dd_mes  sum_dpth_fhsc   dd_mefs     ssrate    ss_dur  \
# 730    경남  2011-01-01  0.764288       0.391150  0.402297  79.270390  9.814327
# 731    경남  2011-01-02  1.886346       0.980215  0.735109  86.101050  9.826702
# 732    경남  2011-01-03  0.402864       0.128711  0.206368  60.515930  9.880832
# 733    경남  2011-01-04  1.655560       1.729570  1.478237  82.075532  9.891057
# 734    경남  2011-01-05  2.550232       1.031719  1.063957  45.110137  9.896472
#
#      sum_ss_hr    min_tg       avg_pa       max_pa       min_pa    avg_pv  \
# 730   7.778412 -9.542650  1013.611646  1019.293847  1008.816611  2.432566
# 731   8.457949 -7.381498  1018.960319  1021.596112  1017.090035  3.287567
# 732   5.983212 -8.615377  1014.973258  1017.216661  1012.964120  3.799341
# 733   8.116806 -7.736761  1014.964045  1016.058158  1013.774118  3.832621
# 734   4.465780 -6.894659  1014.488850  1016.403903  1011.884736  3.402876
#
# ...

# %%
path = "/content/drive/MyDrive/날씨 빅콘/data/전처리데이터"
os.chdir(path)

# %%
weather = pd.read_csv('{}/full_가중치완료_lag.csv'.format(path))
air = pd.read_csv('{}/air_가중치완료_lag.csv'.format(path))

# %%
weather.shape
# Out:
# (37264, 110)

# %%
air.shape
# Out:
# (36899, 22)

# %%
air
# Out:
#        지역         측정일       SO2        CO        O3       NO2       PM10  \
# 0      강원  2011-01-01  0.001384  0.204991  0.002894  0.005240  10.051255
# 1      강원  2011-01-02  0.001390  0.246259  0.002276  0.006155  11.536032
# 2      강원  2011-01-03  0.001326  0.266888  0.002125  0.007304  12.720615
# 3      강원  2011-01-04  0.001285  0.241183  0.002283  0.007152  12.993877
data = pd.merge(weather,air,how='left',right_on=["지역","측정일"],left_on=["where","tma"])

# %%
data
# Out:
#       where         tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate  \
# 0        강원  2011-01-01   7.850279       4.969315  2.892098  49.720459
# 1        강원  2011-01-02   7.931251       0.181203  2.391485  65.170244
# 2        강원  2011-01-03  12.450344       3.307011  5.072551  40.736534
# 3        강원  2011-01-04  18.978367       5.416715  5.420207  65.299808
# 4        강원  2011-01-05   7.124591       1.884490  0.673377  55.632543
# ...     ...         ...        ...            ...       ...        ...
# 37259    세종  2016-12-27   1.600000       0.100000  0.100000  60.800000
# 37260    세종  2016-12-28   1.500000       0.000000  0.000000  87.600000
# 37261    세종  2016-12-29   2.000000       0.300000  0.400000  79.200000
# 37262    세종  2016-12-30   1.800000       0.100000  0.100000  84.700000
# 37263    세종  2016-12-31   0.600000       0.000000  0.000000  11.700000
#
#          ss_dur  sum_ss_hr     min_tg       avg_pa       max_pa       min_pa  \
# ...

# %%
data[data['where']=='세종']
# Out:
#       where         tma  dd_mes  sum_dpth_fhsc  dd_mefs  ssrate  ss_dur  \
# 35072    세종  2011-01-01     4.4            0.4      0.6    67.6     9.7
# 35073    세종  2011-01-02     2.9            0.1      0.1    84.9     9.7
# 35074    세종  2011-01-03     4.8            0.5      0.6    37.8     9.8
# 35075    세종  2011-01-04     3.4            0.2      0.3    11.9     9.8
# 35076    세종  2011-01-05     2.2            0.2      0.3    17.0     9.8
# ...     ...         ...     ...            ...      ...     ...     ...
# 37259    세종  2016-12-27     1.6            0.1      0.1    60.8     9.7
# 37260    세종  2016-12-28     1.5            0.0      0.0    87.6     9.7
# 37261    세종  2016-12-29     2.0            0.3      0.4    79.2     9.7
# 37262    세종  2016-12-30     1.8            0.1      0.1    84.7     9.7
# 37263    세종  2016-12-31     0.6            0.0      0.0    11.7     9.7
#
#        sum_ss_hr  min_tg  avg_pa  max_pa  min_pa  avg_pv  max_pv  min_pv  \
# ...

# %%
data = data.drop(['지역','측정일'],axis=1)

# %%
data
# Out:
#       where         tma     dd_mes  sum_dpth_fhsc   dd_mefs     ssrate  \
# 0        강원  2011-01-01   7.850279       4.969315  2.892098  49.720459
# 1        강원  2011-01-02   7.931251       0.181203  2.391485  65.170244
# 2        강원  2011-01-03  12.450344       3.307011  5.072551  40.736534
# 3        강원  2011-01-04  18.978367       5.416715  5.420207  65.299808
# 4        강원  2011-01-05   7.124591       1.884490  0.673377  55.632543
# ...     ...         ...        ...            ...       ...        ...
# 37259    세종  2016-12-27   1.600000       0.100000  0.100000  60.800000
# 37260    세종  2016-12-28   1.500000       0.000000  0.000000  87.600000
# 37261    세종  2016-12-29   2.000000       0.300000  0.400000  79.200000
# 37262    세종  2016-12-30   1.800000       0.100000  0.100000  84.700000
# 37263    세종  2016-12-31   0.600000       0.000000  0.000000  11.700000
#
#          ss_dur  sum_ss_hr     min_tg       avg_pa       max_pa       min_pa  \
# ...

# %%
data.to_csv("/content/drive/MyDrive/날씨 빅콘/data/전처리데이터/air_weather_lag.csv",index=False)
