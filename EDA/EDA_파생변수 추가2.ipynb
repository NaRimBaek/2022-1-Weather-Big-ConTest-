# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import io
import pandas as pd
import numpy as np
import os
from datetime import datetime

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.dates as dates

# %%
## * 이 셀이 제대로 작동하지 않고 길게 warning 메시지가 나올 경우, 상단의 메뉴에서 <런타임>-<런타임 다시 시작>을 클릭한 뒤 처음부터 코드를 실행하세요 
# 그래프 한글 폰트 설정

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %config InlineBackend.figure_format = 'retina'

#폰트 설치
# !apt -qq -y install fonts-nanum

#기본 폰트로 지정
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

from IPython.display import set_matplotlib_formats
#폰트 선명하게 보이게 하기 위해
set_matplotlib_formats('retina')

## Test
plt.figure(figsize=(2,2))
plt.text(0.3, 0.3, '한글 폰트 테스트', size=15)
plt.show()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dat = pd.read_csv('/content/drive/MyDrive/날씨 빅콘/data/전처리데이터/train_test/ver_0806/train_0806_2.csv')

# %% [markdown]
# #지역별 성별 frequency 그래프

# %%
#필요한 변수만 뽑기
dat = dat.loc[:,['yyyymmdd','area','sex','frequency']]
dat.head()
# Out:
#      yyyymmdd area  sex  frequency
# 0  2012-01-01   강원    1        3.0
# 1  2012-01-01   강원    2        3.0
# 2  2012-01-01   경기    1        4.0
# 3  2012-01-01   경기    2        5.0
# 4  2012-01-01   경남    1        2.0

# %% [markdown]
# # 1. frequency 박스플랏
# > 경기 서울
#
# > 경남 경북 부산
#
# > 강원 대구 인천 전북 충남 충북
#
# > 광주 대전 울산
#
# > 전남 제주

# %%
plt.figure(figsize=(10,8))
box=sns.boxplot(x ='area',y='frequency',data=dat)
box.set_xlabel('area')
box.set_ylabel("frequency")
plt.show()

# %% [markdown]
# # 2. 지역별 frequency 추세

# %%
sns.lineplot(x= 'yyyymmdd', y='frequency', hue='area', data=dat)

# %%
gangwon = dat.loc[dat['area']=='강원']
sns.lineplot(x= 'yyyymmdd', y='frequency', hue='sex', data=gangwon)

# %%
gangwon = dat.loc[dat['area']=='강원']
sns.lineplot(x= 'yyyymmdd', y='frequency',data=gangwon)

# %%
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='경기'])

# %%
#area_lst=['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '서울', '세종', '울산',
#       '인천', '전남', '전북', '제주', '충남', '충북']

fig, ax = plt.subplots(ncols=4, nrows=5,  figsize=(20,20))

#for i in area_lst:
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='강원', ax=ax[0,0]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='경기',ax=ax[0,1]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='경남',ax=ax[0,2]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='경북',ax=ax[0,3]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='광주',ax=ax[1,0]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='대구',ax=ax[1,1]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='대전',ax=ax[1,2]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='부산',ax=ax[1,3]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='서울',ax=ax[2,0]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='세종',ax=ax[2,1]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='울산',ax=ax[2,2]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='인천',ax=ax[2,3]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='전남',ax=ax[3,0]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='전북',ax=ax[3,1]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='제주',ax=ax[3,2]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='충남',ax=ax[3,3]])
sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='충북',ax=ax[4,0]])
# Out:
#   File "<ipython-input-8-6a6cce07f984>", line 7
#     sns.lineplot(x= 'yyyymmdd', y='frequency',data=dat.loc[dat['area']=='강원',ax=ax[0,0]])
#                                                                                ^
# SyntaxError: invalid syntax
